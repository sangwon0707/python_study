# %%
from dateutil.parser import parse
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os

# %%
# file_path = '/2025-09-06/dataset/amb_hour_time.csv'
file_path = 'C:/project_personal/python_test/2025-09-06/dataset/amb_hour_time.csv'
df = pd.read_csv(file_path)
df
# Out:
#                  date  PM10  PM2.5     O3    NO2   CO    SO2
# 0     2022-05-24 0:00  45.0   27.0  0.041  0.007  0.2  0.002
# 1     2022-05-24 1:00  49.0   29.0  0.042  0.009  0.2  0.003
# 2     2022-05-24 2:00  42.0   30.0  0.038  0.010  0.2  0.003
# 3     2022-05-24 3:00  46.0   30.0  0.035  0.012  0.2  0.003
# 4     2022-05-24 4:00  46.0   36.0  0.030  0.014  0.3  0.002
# ..                ...   ...    ...    ...    ...  ...    ...
# 571  2022-06-16 19:00  11.0    7.0  0.028  0.004  0.2  0.002
# 572  2022-06-16 20:00  13.0    6.0  0.024  0.009  0.2  0.002
# 573  2022-06-16 21:00  14.0    7.0  0.022  0.011  0.2  0.002
# 574  2022-06-16 22:00  14.0    8.0  0.021  0.013  0.2  0.002
# 575  2022-06-16 23:00  13.0    8.0  0.027  0.008  0.2  0.002
#
# [576 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    576 non-null    object
#  1   PM10    573 non-null    float64
#  2   PM2.5   557 non-null    float64
#  3   O3      574 non-null    float64
#  4   NO2     574 non-null    float64
#  5   CO      574 non-null    float64
#  6   SO2     573 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 31.6+ KB

# %%
df['new_date'] = pd.to_datetime(df['date'])
df
# Out:
#                  date  PM10  PM2.5     O3    NO2   CO    SO2  \
# 0     2022-05-24 0:00  45.0   27.0  0.041  0.007  0.2  0.002
# 1     2022-05-24 1:00  49.0   29.0  0.042  0.009  0.2  0.003
# 2     2022-05-24 2:00  42.0   30.0  0.038  0.010  0.2  0.003
# 3     2022-05-24 3:00  46.0   30.0  0.035  0.012  0.2  0.003
# 4     2022-05-24 4:00  46.0   36.0  0.030  0.014  0.3  0.002
# ..                ...   ...    ...    ...    ...  ...    ...
# 571  2022-06-16 19:00  11.0    7.0  0.028  0.004  0.2  0.002
# 572  2022-06-16 20:00  13.0    6.0  0.024  0.009  0.2  0.002
# 573  2022-06-16 21:00  14.0    7.0  0.022  0.011  0.2  0.002
# 574  2022-06-16 22:00  14.0    8.0  0.021  0.013  0.2  0.002
# 575  2022-06-16 23:00  13.0    8.0  0.027  0.008  0.2  0.002
#
#                new_date
# 0   2022-05-24 00:00:00
# 1   2022-05-24 01:00:00
# 2   2022-05-24 02:00:00
# 3   2022-05-24 03:00:00
# 4   2022-05-24 04:00:00
# ..                  ...
# 571 2022-06-16 19:00:00
# 572 2022-06-16 20:00:00
# 573 2022-06-16 21:00:00
# 574 2022-06-16 22:00:00
# 575 2022-06-16 23:00:00
#
# [576 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      576 non-null    object
#  1   PM10      573 non-null    float64
#  2   PM2.5     557 non-null    float64
#  3   O3        574 non-null    float64
#  4   NO2       574 non-null    float64
#  5   CO        574 non-null    float64
#  6   SO2       573 non-null    float64
#  7   new_date  576 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 36.1+ KB

# %%
df['new_date'].dt.hour
# Out:
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#        ..
# 571    19
# 572    20
# 573    21
# 574    22
# 575    23
# Name: new_date, Length: 576, dtype: int32

# %%
df['date'] = df['new_date'].dt.date
df['hour'] = df['new_date'].dt.hour
df
# Out:
#            date  PM10  PM2.5     O3    NO2   CO    SO2            new_date  \
# 0    2022-05-24  45.0   27.0  0.041  0.007  0.2  0.002 2022-05-24 00:00:00
# 1    2022-05-24  49.0   29.0  0.042  0.009  0.2  0.003 2022-05-24 01:00:00
# 2    2022-05-24  42.0   30.0  0.038  0.010  0.2  0.003 2022-05-24 02:00:00
# 3    2022-05-24  46.0   30.0  0.035  0.012  0.2  0.003 2022-05-24 03:00:00
# 4    2022-05-24  46.0   36.0  0.030  0.014  0.3  0.002 2022-05-24 04:00:00
# ..          ...   ...    ...    ...    ...  ...    ...                 ...
# 571  2022-06-16  11.0    7.0  0.028  0.004  0.2  0.002 2022-06-16 19:00:00
# 572  2022-06-16  13.0    6.0  0.024  0.009  0.2  0.002 2022-06-16 20:00:00
# 573  2022-06-16  14.0    7.0  0.022  0.011  0.2  0.002 2022-06-16 21:00:00
# 574  2022-06-16  14.0    8.0  0.021  0.013  0.2  0.002 2022-06-16 22:00:00
# 575  2022-06-16  13.0    8.0  0.027  0.008  0.2  0.002 2022-06-16 23:00:00
#
#      hour
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
# ..    ...
# 571    19
# 572    20
# 573    21
# 574    22
# 575    23
#
# [576 rows x 9 columns]

# %%
def plot_df(df, x, y, title="", xlabel='hour', ylabel='PM10', dpi=100):
    plt.figure(figsize=(5,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')  # df[x], df[y] → x, y로 변경
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.gca().axes.xaxis.set_visible(False)
    plt.ylim(0,100)

    pic_name = title + ".png"
    plt.savefig(pic_name)

    plt.show()

# %%
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

for x in range(24):
    plot_df(
        df,
        x=df.hour[x*24:(x+1)*24],
        y=df.PM10[x*24:(x+1)*24],
        title=str(df.date[x*24])
    )

# %%
import matplotlib.image as mpimg
import cv2
import tensorflow as tf
from tensorflow import keras
file_path = 'C:/project_personal/python_test/2025-09-06/2022-05-24.png'
img = mpimg.imread(file_path)
plt.imshow(img)
img.shape
# Out:
# (500, 500, 4)

# %%
img2 = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
newimg = img2[65:445, 65:445]
print('newimg.shape:', newimg.shape)
cv2.imwrite("newimg.png", newimg)

cv2.imshow('img2', img2)
cv2.imshow('new', newimg)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# newimg.shape: (380, 380)

# %%
img3 = cv2.imread('newimg.png', cv2.IMREAD_GRAYSCALE)
img3 = cv2.resize(img3, (28, 28))
plt.imshow(img3)
img3.shape
# Out:
# (28, 28)

# %%
model = keras.models.load_model('myFMNIST.h5')
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,148 (434.18 KB)
#  Trainable params: 111,146 (434.16 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
input_data = img3[np.newaxis, :, :]
input_data.shape
# Out:
# (1, 28, 28)

# %%
class_name = ['Type1', 'Type2', 'Type3', 'Type4', 'Type5', \
              'Type6', 'Type7', 'Type8', 'Type9', 'Type10']
y = np.argmax(model.predict(input_data))
print(class_name[y])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Type9
